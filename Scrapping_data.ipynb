# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.10/dist-packages (1.2.7)

# %%
from google_play_scraper import app, reviews_all, Sort

scrapreview = reviews_all(
    'mam.reader.ipusnas',
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=10000
)

# %%
import csv

with open('ipusnas_review.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in scrapreview:
        writer.writerow([review['content']])

# %%
import pandas as pd
import csv

df = pd.DataFrame(scrapreview)
df.shape
df.head()
df.to_csv('ipusnas_review.csv', index=False)

# %%
df = pd.DataFrame(scrapreview)
jumlah_ulasan, jumlah_kolom = df.shape

# %%
df.head()
# Out:
#                                reviewId         userName  \
# 0  07b2cda0-6cee-4f81-bb6e-b612c8921797  Pengguna Google
# 1  05a4e2d2-91ea-4d42-8a95-7fdab0b52a80  Pengguna Google
# 2  b8a2c54f-5c50-4799-a7b7-636e09655a29  Pengguna Google
# 3  bdff14cb-2361-403e-b3ab-95ad79bbcb81  Pengguna Google
# 4  2cc3b0c6-0963-47c6-a006-d471df906aac  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0          Hari ini kok gak bisa dibuka aplikasinya?      3              0
# 1                      vertifikasi kgk muncul muncul      1              0
# 2                     Susah taiiii, banyak errornyaa      1              0
# 3  Ayolah pemerintah lebih urus ni aplikasi, ipus...      5              0
# 4                           Sering tidak bisa dibuka      5              0
#
#   reviewCreatedVersion                  at  \
# 0                1.6.4 2024-07-30 16:10:48
# 1                1.6.4 2024-07-30 00:27:16
# 2                1.6.4 2024-07-29 16:06:36
# 3                1.6.4 2024-07-29 12:20:36
# 4                1.6.4 2024-07-28 17:47:35
#
#                                         replyContent           repliedAt  \
# 0  Hallo Firdaus! Kami mohon maaf atas kendala da... 2024-07-31 01:29:40
# 1  Hallo Senn! Kami mohon maaf atas ketidaknyaman... 2024-07-30 01:36:35
# 2  Hallo Rizky! Kami mohon maaf atas kendala dan ... 2024-07-30 01:33:51
# 3  Hallo Orang! Kami mohon maaf atas ketidaknyama... 2024-07-30 01:33:34
# 4  Hallo Chan! Kami mohon maaf atas kendala dan k... 2024-07-28 23:06:53
#
#   appVersion
# 0      1.6.4
# 1      1.6.4
# 2      1.6.4
# 3      1.6.4
# 4      1.6.4
